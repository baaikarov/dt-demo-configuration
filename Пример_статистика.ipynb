# %%
import pandas as pd
import numpy as np
# import scipy as ss
import seaborn as sns
import matplotlib as plt
from scipy import stats as ss
import plotly.express as px
import statsmodels.stats.multicomp as mlt
import statsmodels as sm

# %%
# Задание на поиск стандартного отклонения
seria_1_99 = list(range(0, 100))
round(np.std(seria_1_99, ddof=1),3)
# новый комент
# Out:
# 29.011

# %%
games= pd.read_csv('https://stepik.org/media/attachments/lesson/383837/games.csv')
game_work= games.dropna(axis=0)
games.Name.count() -game_work.Name.count()
game_work.Year.describe()
sns.countplot(game_work.Year)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
ss.stats.mode(game_work.Publisher)
value_count_platform=game_work.Platform.value_counts(normalize=True)*100
game_work.Publisher.value_counts().head()
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
# Name: Publisher, dtype: int64

# %%
fig = px.box(Nintendo_game, x="Genre", y="JP_Sales")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="029054d3-a3ed-43f0-9f53-d21268b8b6e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("029054d3-a3ed-43f0-9f53-d21268b8b6e2")) {
#                     Plotly.newPlot(
#                         '029054d3-a3ed-43f0-9f53-d21268b8b6e2',
# ...

# %%
fig = px.bar(Nintendo_game, x="Year", y="Global_Sales", color="Genre")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3951fb83-966e-442c-98cb-581a42c6e39c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3951fb83-966e-442c-98cb-581a42c6e39c")) {
#                     Plotly.newPlot(
#                         '3951fb83-966e-442c-98cb-581a42c6e39c',
# ...
